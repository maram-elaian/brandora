# %%
[
  {
    "id": "B001",
    "category": "Food & Beverage",
    "industry": "Specialty Coffee",
    "description": "A modern coffee shop targeting university students and freelancers.",
    "target_audience": "University students, remote workers, ages 18-30",
    "desired_personality": ["modern", "friendly", "energetic", "welcoming"],
    "preferred_style": ["minimal", "clean", "warm"],
    "tone": "casual and inspiring"
  },
  {
    "id": "B002",
    "category": "Technology",
    "industry": "Cybersecurity Software",
    "description": "An enterprise-level cybersecurity platform protecting small businesses.",
    "target_audience": "Small to medium business owners, IT managers",
    "desired_personality": ["secure", "reliable", "professional", "authoritative"],
    "preferred_style": ["sleek", "corporate", "trustworthy"],
    "tone": "serious and confident"
  },
  {
    "id": "B003",
    "category": "Fashion & Beauty",
    "industry": "Sustainable Skincare",
    "description": "An organic, cruelty-free skincare brand using locally sourced ingredients.",
    "target_audience": "Eco-conscious women, ages 25-45",
    "desired_personality": ["natural", "pure", "luxurious", "ethical"],
    "preferred_style": ["earthy", "elegant", "soft"],
    "tone": "calm and sophisticated"
  },
  {
    "id": "B004",
    "category": "Fitness & Wellness",
    "industry": "Home Workout App",
    "description": "A gamified mobile application that makes home workouts fun and rewarding.",
    "target_audience": "Beginners to fitness, busy professionals",
    "desired_personality": ["motivational", "fun", "dynamic", "accessible"],
    "preferred_style": ["bold", "colorful", "energetic"],
    "tone": "upbeat and encouraging"
  },
  {
    "id": "B005",
    "category": "Education",
    "industry": "Kids Coding Academy",
    "description": "An after-school program teaching robotics and coding to children through play.",
    "target_audience": "Parents of children ages 7-12",
    "desired_personality": ["playful", "innovative", "safe", "educational"],
    "preferred_style": ["cartoonish", "bright", "engaging"],
    "tone": "fun and reassuring"
  },
  {
    "id": "B006",
    "category": "Lifestyle / Services",
    "industry": "Premium Pet Sitting",
    "description": "A luxury pet sitting and walking service for high-end urban neighborhoods.",
    "target_audience": "Affluent pet owners who treat pets as family",
    "desired_personality": ["caring", "premium", "trustworthy", "exclusive"],
    "preferred_style": ["refined", "classic", "minimalist"],
    "tone": "warm and professional"
  }
]
###
# Out:
# [{'id': 'B001',
#   'category': 'Food & Beverage',
#   'industry': 'Specialty Coffee',
#   'description': 'A modern coffee shop targeting university students and freelancers.',
#   'target_audience': 'University students, remote workers, ages 18-30',
#   'desired_personality': ['modern', 'friendly', 'energetic', 'welcoming'],
#   'preferred_style': ['minimal', 'clean', 'warm'],
#   'tone': 'casual and inspiring'},
#  {'id': 'B002',
#   'category': 'Technology',
#   'industry': 'Cybersecurity Software',
#   'description': 'An enterprise-level cybersecurity platform protecting small businesses.',
#   'target_audience': 'Small to medium business owners, IT managers',
#   'desired_personality': ['secure',
#    'reliable',
#    'professional',
#    'authoritative'],
#   'preferred_style': ['sleek', 'corporate', 'trustworthy'],
#   'tone': 'serious and confident'},
#  {'id': 'B003',
#   'category': 'Fashion & Beauty',
#   'industry': 'Sustainable Skincare',
# ...
